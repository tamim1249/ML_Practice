# %%
#13/06/2025
#Tamim Mahmud from Daffodil International University
import pandas as pd

# %%
df=pd.read_csv('heart.csv')
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# ...

# %%
df.tail(5)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
df.shape
# Out:
# (1025, 14)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
print(df['age'])
# Out:
# 0       52
# 1       53
# 2       70
# 3       61
# 4       62
#         ..
# 1020    59
# 1021    60
# 1022    47
# 1023    50
# 1024    54
# Name: age, Length: 1025, dtype: int64

# %%
print(df['age'][1020:])
# Out:
# 1020    59
# 1021    60
# 1022    47
# 1023    50
# 1024    54
# Name: age, dtype: int64

# %%
print(df[['age','sex']][:5])
# Out:
#    age  sex
# 0   52    1
# 1   53    1
# 2   70    1
# 3   61    1
# 4   62    0

# %%
df.iloc[1024]
# Out:
# age          54.0
# sex           1.0
# cp            0.0
# trestbps    120.0
# chol        188.0
# fbs           0.0
# restecg       1.0
# thalach     113.0
# exang         0.0
# oldpeak       1.4
# slope         1.0
# ca            1.0
# thal          3.0
# target        0.0
# Name: 1024, dtype: float64

# %%
df.iloc[:4]
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0

# %%
df.iloc[1020:]
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
df.iloc[1,3] #specific location
# Out:
# 140

# %%
df.iloc[1024,7]
# Out:
# 113

# %%
df.loc[df['age']==75]
# Out:
# Empty DataFrame
# Columns: [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, target]
# Index: []

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
df.sort_values('age')
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 60    29    1   1       130   204    0        0      202      0      0.0
# 118   29    1   1       130   204    0        0      202      0      0.0
# 668   29    1   1       130   204    0        0      202      0      0.0
# 64    29    1   1       130   204    0        0      202      0      0.0
# 572   34    1   3       118   182    0        0      174      0      0.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 99    76    0   2       140   197    0        2      116      0      1.1
# 965   76    0   2       140   197    0        2      116      0      1.1
# 160   77    1   0       125   304    0        0      162      1      0.0
# 162   77    1   0       125   304    0        0      162      1      0.0
# 387   77    1   0       125   304    0        0      162      1      0.0
#
#      slope  ca  thal  target
# 60       2   0     2       1
# 118      2   0     2       1
# ...

# %%
df.sort_values(['age','sex'],ascending=False)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 160   77    1   0       125   304    0        0      162      1      0.0
# 162   77    1   0       125   304    0        0      162      1      0.0
# 387   77    1   0       125   304    0        0      162      1      0.0
# 99    76    0   2       140   197    0        2      116      0      1.1
# 535   76    0   2       140   197    0        2      116      0      1.1
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 779   34    0   1       118   210    0        1      192      0      0.7
# 60    29    1   1       130   204    0        0      202      0      0.0
# 64    29    1   1       130   204    0        0      202      0      0.0
# 118   29    1   1       130   204    0        0      202      0      0.0
# 668   29    1   1       130   204    0        0      202      0      0.0
#
#      slope  ca  thal  target
# 160      2   3     2       0
# 162      2   3     2       0
# ...

# %%
df.sort_values(('sex'),ascending=True)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 302    55    0   1       132   342    0        1      166      0      1.2
# 754    51    0   2       130   256    0        0      149      0      0.5
# 372    54    0   2       110   214    0        1      158      0      1.6
# 370    43    0   0       132   341    1        0      136      1      3.0
# 758    46    0   1       105   204    0        1      172      0      0.0
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 389    63    1   3       145   233    1        0      150      0      2.3
# 391    45    1   3       110   264    0        1      132      0      1.2
# 392    51    1   2       110   175    0        1      123      0      0.6
# 441    60    1   0       140   293    0        0      170      0      1.2
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 302       2   0     2       1
# ...

# %%
df.sort_values(['age','sex'],ascending=[1,1])
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 60    29    1   1       130   204    0        0      202      0      0.0
# 64    29    1   1       130   204    0        0      202      0      0.0
# 118   29    1   1       130   204    0        0      202      0      0.0
# 668   29    1   1       130   204    0        0      202      0      0.0
# 12    34    0   1       118   210    0        1      192      0      0.7
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 535   76    0   2       140   197    0        2      116      0      1.1
# 965   76    0   2       140   197    0        2      116      0      1.1
# 160   77    1   0       125   304    0        0      162      1      0.0
# 162   77    1   0       125   304    0        0      162      1      0.0
# 387   77    1   0       125   304    0        0      162      1      0.0
#
#      slope  ca  thal  target
# 60       2   0     2       1
# 64       2   0     2       1
# ...

# %%
df['Tamim']=df[['ca','thal','target','oldpeak']].sum(axis=1)
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target  Tamim
# 0   2     3       0    6.0
# 1   0     3       0    6.1
# 2   0     3       0    5.6
# 3   1     3       0    4.0
# 4   3     2       0    6.9

# %%
df['Sinthia']=df[['Tamim','cp']].sum(axis=1)
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target  Tamim  Sinthia
# 0   2     3       0    6.0      6.0
# 1   0     3       0    6.1      6.1
# 2   0     3       0    5.6      5.6
# 3   1     3       0    4.0      4.0
# 4   3     2       0    6.9      6.9

# %%
df.drop(['cp'],axis='columns')
# Out:
#       age  sex  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0      52    1       125   212    0        1      168      0      1.0      2
# 1      53    1       140   203    1        0      155      1      3.1      0
# 2      70    1       145   174    0        1      125      1      2.6      0
# 3      61    1       148   203    0        1      161      0      0.0      2
# 4      62    0       138   294    1        1      106      0      1.9      1
# ...   ...  ...       ...   ...  ...      ...      ...    ...      ...    ...
# 1020   59    1       140   221    0        1      164      1      0.0      2
# 1021   60    1       125   258    0        0      141      1      2.8      1
# 1022   47    1       110   275    0        0      118      1      1.0      1
# 1023   50    0       110   254    0        0      159      0      0.0      2
# 1024   54    1       120   188    0        1      113      0      1.4      1
#
#       ca  thal  target  Tamim  Sinthia
# ...

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# Tamim       0
# Sinthia     0
# dtype: int64

# %%
sd=pd.read_csv('pokemon_data.csv')
sd
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
sd.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
sd['Type 2'].fillna(sd['Type 2'].mode()[0],inplace=True)

# %%
sd.isnull().sum()
# Out:
# #             0
# Name          0
# Type 1        0
# Type 2        0
# HP            0
# Attack        0
# Defense       0
# Sp. Atk       0
# Sp. Def       0
# Speed         0
# Generation    0
# Legendary     0
# dtype: int64

# %%
df=pd.read_csv('sample_student_data.csv')
df
# Out:
#      ID  Age  Gender Department  Score Remarks
# 0     1   56    Male        EEE   56.0    Good
# 1     2   46  Female        CSE   88.0    Poor
# 2     3   32  Female        CSE   49.0    Poor
# 3     4   25  Female        BBA   22.0     NaN
# 4     5   38    Male        EEE   30.0    Good
# ..  ...  ...     ...        ...    ...     ...
# 95   96   59    Male        EEE   98.0    Good
# 96   97   56  Female        ENG   36.0    Good
# 97   98   58  Female        CSE    NaN     NaN
# 98   99   45    Male        BBA   92.0    Good
# 99  100   24    Male        ENG   45.0     NaN
#
# [100 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# ID             0
# Age            0
# Gender         0
# Department     0
# Score         15
# Remarks       24
# dtype: int64

# %%
df['Remarks'].fillna(df['Remarks'].mode()[0],inplace=True)

# %%
tr.isnull().sum()
# Out:
# ID            0
# Age           0
# Gender        0
# Department    0
# Score         0
# Remarks       0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'Department', 'Score', 'Remarks'], dtype='object')

# %%
df.isnull().sum()
# Out:
# ID            0
# Age           0
# Gender        0
# Department    0
# Score         0
# Remarks       0
# dtype: int64

# %%
df.rename(columns={'Remarks':'Tamim'},inplace=True)

# %%
df.head()
# Out:
#    ID  Age  Gender Department  Score    Tamim
# 0   1   56    Male        EEE   56.0     Good
# 1   2   46  Female        CSE   88.0     Poor
# 2   3   32  Female        CSE   49.0     Poor
# 3   4   25  Female        BBA   22.0  Average
# 4   5   38    Male        EEE   30.0     Good

# %%
df.rename(columns={'Department':'Dept'},inplace=True)
df.head()
# Out:
#    ID  Age  Gender Dept  Score    Tamim
# 0   1   56    Male  EEE   56.0     Good
# 1   2   46  Female  CSE   88.0     Poor
# 2   3   32  Female  CSE   49.0     Poor
# 3   4   25  Female  BBA   22.0  Average
# 4   5   38    Male  EEE   30.0     Good

# %%
df.groupby('Tamim')['Age'].mean()
# Out:
# Tamim
# Average    35.870370
# Good       42.857143
# Poor       38.160000
# Name: Age, dtype: float64

# %%
df.groupby('Dept')['Score'].mean()
# Out:
# Dept
# BBA    38.127059
# CSE    43.708556
# EEE    59.549020
# ENG    46.488971
# Name: Score, dtype: float64

# %%
df['Tamim'].value_counts()
# Out:
# Tamim
# Average    54
# Poor       25
# Good       21
# Name: count, dtype: int64

# %%
df['Score'].value_counts()
# Out:
# Score
# 46.529412    15
# 98.000000     4
# 32.000000     4
# 47.000000     4
# 92.000000     3
# 29.000000     3
# 53.000000     3
# 26.000000     2
# 34.000000     2
# 20.000000     2
# 7.000000      2
# 88.000000     2
# 19.000000     2
# 79.000000     2
# 18.000000     2
# 37.000000     2
# 36.000000     2
# 68.000000     2
# 45.000000     2
# 63.000000     2
# 6.000000      2
# 50.000000     1
# 58.000000     1
# 91.000000     1
# 43.000000     1
# 16.000000     1
# 75.000000     1
# 21.000000     1
# 85.000000     1
# 99.000000     1
# 48.000000     1
# 3.000000      1
# 27.000000     1
# 97.000000     1
# 67.000000     1
# 56.000000     1
# 40.000000     1
# 11.000000     1
# 49.000000     1
# 22.000000     1
# 30.000000     1
# 93.000000     1
# 15.000000     1
# 59.000000     1
# 1.000000      1
# 0.000000      1
# 31.000000     1
# 60.000000     1
# 8.000000      1
# 23.000000     1
# 74.000000     1
# 71.000000     1
# 35.000000     1
# 24.000000     1
# 81.000000     1
# ...

# %%
df['Tamim'].apply(lambda x:x*2)
# Out:
# 0           GoodGood
# 1           PoorPoor
# 2           PoorPoor
# 3     AverageAverage
# 4           GoodGood
#            ...
# 95          GoodGood
# 96          GoodGood
# 97    AverageAverage
# 98          GoodGood
# 99    AverageAverage
# Name: Tamim, Length: 100, dtype: object

# %%
df['Score'].apply(lambda x: x+2)
# Out:
# 0      58.000000
# 1      90.000000
# 2      51.000000
# 3      24.000000
# 4      32.000000
#          ...
# 95    100.000000
# 96     38.000000
# 97     48.529412
# 98     94.000000
# 99     47.000000
# Name: Score, Length: 100, dtype: float64

# %%
#create DataFrane

df1=pd.DataFrame({
    'Id':[1,2,3,4],
    'Name':['Tamim','Sinthia','Farjana','Rimi']
            })
df2=pd.DataFrame({
    'Id':[1,2,5,4],
    'CGPA':[3.44,3.03,3.78,3.48]
})
df1
# Out:
#    Id     Name
# 0   1    Tamim
# 1   2  Sinthia
# 2   3  Farjana
# 3   4     Rimi

# %%
df2
# Out:
#    Id  CGPA
# 0   1  3.44
# 1   2  3.03
# 2   5  3.78
# 3   4  3.48

# %%
s=pd.merge(df1,df2)
s
# Out:
#    Id     Name  CGPA
# 0   1    Tamim  3.44
# 1   2  Sinthia  3.03
# 2   4     Rimi  3.48

# %%
pd.merge(df1,df2,on='Id',how='inner')
# Out:
#    Id     Name  CGPA
# 0   1    Tamim  3.44
# 1   2  Sinthia  3.03
# 2   4     Rimi  3.48

# %%
pd.merge(df1,df2,on='Id',how='right')
# Out:
#    Id     Name  CGPA
# 0   1    Tamim  3.44
# 1   2  Sinthia  3.03
# 2   5      NaN  3.78
# 3   4     Rimi  3.48

# %%
pd.merge(df1,df2,on='Id',how='outer')
# Out:
#    Id     Name  CGPA
# 0   1    Tamim  3.44
# 1   2  Sinthia  3.03
# 2   3  Farjana   NaN
# 3   4     Rimi  3.48
# 4   5      NaN  3.78

# %%
df['Tamim'].unique()
# Out:
# array(['Good', 'Poor', 'Average'], dtype=object)

# %%
df['Tamim'].nunique()
# Out:
# 3

# %%
df['Dept'].unique()
# Out:
# array(['EEE', 'CSE', 'BBA', 'ENG'], dtype=object)

# %%
df['Dept'].nunique()
# Out:
# 4

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
sd.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
#Alhamdulillah
#13/06/2025
